# %% [markdown]
# # Sphere

# %%
# %matplotlib widget

import plot_functions as plf

# %%
plf.sphere_gravity_potential_reference(figure_size=7)
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plf.sphere_gravity_potential_disturbed(figure_size=7)
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plf.sphere_gravity_potential_disturbed(figure_size=7, reference=False)
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
