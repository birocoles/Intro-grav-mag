# %% [markdown]
# # Vector analysis - part 1

# %%
# %matplotlib widget

import plot_functions as plf

# %% [markdown]
# ## Single vector

# %%
plf.single_vector(figure_size=7)
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Scalar (dot) product

# %%
plf.scalar_product(figure_size=7)
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Cross product

# %%
plf.vector_product(figure_size=7)
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
