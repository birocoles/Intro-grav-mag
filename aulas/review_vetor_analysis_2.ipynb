# %% [markdown]
# # Vector analysis - part 2

# %%
# %matplotlib widget

import plot_functions as plf

# %% [markdown]
# ## Rotation of vector coordinates - two objects in the same coordinate system

# %%
plf.rotation_coordinates()
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Rotation of vector base - the same object in two coordinate systems

# %%
plf.rotation_base(figure_size=7)
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
